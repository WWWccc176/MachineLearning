# %%
# =============================================
# Standard Solution: PyTorch Feedforward Network
# =============================================

import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt

# 0. Set the random seed for torch
# TODO

# 1. Data: y = sin(x)
# TODO: create data x (-pi to pi) and y for sin function using linspace
x = 
y = 

# 2. Define model: 1 -> 16 -> 16 -> 1
# TODO: create layers in the nn.Sequential() -- 2 hidden layer and 1 output layer
model = nn.Sequential(

)

# 3. Forward-only prediction (no training)
model.eval()
with torch.no_grad():
    y_pred = model(x)

# 4. Compute MSE loss
# TODO
mse = 
print(f"MSE (random weights): {mse.item():.6f}")

# 5. Visualization
# TODO: visualize ground truth data and model prediction on the same figure

# %%
# ============================================================
# Practice: Exploring CNN Layers in PyTorch (Grayscale Version)
# ============================================================

import torch
import torch.nn as nn
import torchvision.transforms as T
from PIL import Image
import matplotlib.pyplot as plt

# 1. Load and preprocess a grayscale image (400x400)
img = Image.open("example.png").convert("L")  # convert to grayscale ('L' mode)
transform = T.Compose([
    T.Resize((400, 400)),
    T.ToTensor()           # shape: (1, H, W)
])


# 2. Add one more dimension (batch) to the tensor such that data x looks like (1,1,400,400)
# TODO:
x = 


# 2. Define convolution layers
# TODO: use nn.Conv2d to create 3 layers with given setting
conv1 = 
conv2 = 
conv3 = 

# 3. Forward pass through each convolution layer
with torch.no_grad():
    y1 = conv1(x)
    y2 = conv2(x)
